# %% [markdown]
# Importing relevant modules from elsewhere in the repo

# %%
import run_centralforce_sindy
import get_planetary_data
# Out:
# [ 0.33732769 -1.26285052 -0.58814818]
# [ 0.35143728 -1.25852274 -0.58654365] AU
# <SkyCoord (GCRS: obstime=2026-01-01 00:00:00.000, obsgeoloc=(0., 0., 0.) m, obsgeovel=(0., 0., 0.) m / s): (ra, dec, distance) in (deg, deg, km)
#     (283.48278708, -23.75220962, 3.60635403e+08)>

# %% [markdown]
# Create a planetary dataset
# One earth year, 1000 points per year

# %%
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# array([[-3.06664368e-03, -5.12880054e-03, -2.08015833e-03, ...,
#          9.50430196e+00,  3.83380515e-01, -2.51012602e-01],
#        [-3.06402196e-03, -5.12872063e-03, -2.08017780e-03, ...,
#          9.50413526e+00,  3.85257189e-01, -2.50230265e-01],
#        [-3.06140057e-03, -5.12863960e-03, -2.08019679e-03, ...,
#          9.50396811e+00,  3.87133846e-01, -2.49447916e-01],
#        ...,
#        [-7.09539351e-04, -4.50551654e-03, -1.86294665e-03, ...,
# ...

# %% [markdown]
# Run SINDy on our dataset

# %%
run_centralforce_sindy.run_centralforce_sindy(
    "allPlanets_1years_1000per.pickle",
    fileFormat="pickle"
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pysindy/utils/_axes.py:126: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pysindy/utils/_axes.py:126: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pysindy/utils/_axes.py:126: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pysindy/utils/_axes.py:126: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pysindy/utils/_axes.py:126: AxesWarning: 2 axes labeled for array with 1 axes
#   warnings.warn(
# ...

# %% [markdown]
# Create a dataset 5x longer

# %%
get_planetary_data.extract_multiplanetary_data(
    5,
    1/1e3,
    doPickle=True,
    pickleFilename="allPlanets_5years_1000per.pickle")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "taiutc" yielded 2002 of "dubious year (Note 4)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...

# %%
run_centralforce_sindy.run_centralforce_sindy(
    "allPlanets_5years_1000per.pickle",
    fileFormat="pickle",
    excludeCols=[6]
)
# Out:
# [18, 19, 20]
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 7.8743e+04 ... 0.0000e+00 ...          5 ... 7.8743e+04
# (x0)' = -0.002 u2 u3 + -0.003 u4 u5 + -0.001 u6 u7 + -0.866 u8 u9
# 5.075074228633181e-05
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 7.3526e+04 ... 0.0000e+00 ...          5 ... 7.3526e+04
# (x0)' = -986.684 u0 u1 +  0.046 u2 u3 +  0.122 u4 u5 +  0.333 u6 u7 + -0.964 u8 u9
# 0.9999997031793111
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 5.1612e+02 ... 0.0000e+00 ...          5 ... 5.1612e+02
# (x0)' = -987.012 u0 u1 + -0.001 u2 u3 + -0.003 u4 u5 +  0.006 u6 u7 + -0.768 u8 u9
# 0.9999999709853246
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
# ...

# %% [markdown]
# Now try it with 5x the resolution for 1 year

# %%
get_planetary_data.extract_multiplanetary_data(
    1,
    1/5e3,
    doPickle=True,
    pickleFilename="allPlanets_1years_5000per.pickle")
run_centralforce_sindy.run_centralforce_sindy(
    "allPlanets_1years_5000per.pickle",
    fileFormat="pickle",
    excludeCols=[6]
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# [18, 19, 20]
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 2.3743e+00 ... 0.0000e+00 ...          5 ... 2.3743e+00
# (x0)' = -0.036 u8 u9
# 0.003007831995395227
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.6708e+01 ... 0.0000e+00 ...          5 ... 1.6708e+01
# (x0)' = -39.438 u0 u1 +  0.003 u2 u3 + -0.003 u4 u5 + -0.027 u6 u7 + -0.066 u8 u9
# 0.9999999566752648
# ...

# %%
import run_centralforce_sindy

# 50 years, 100 data points per year
if False:
    get_planetary_data.extract_multiplanetary_data(
        50,
        1/1e2,
        doPickle=True,
        pickleFilename="allPlanets_50years_100per.pickle")
run_centralforce_sindy.run_centralforce_sindy(
    "allPlanets_50years_100per.pickle",
    fileFormat="pickle",
    excludeCols=[6],
    doMerged=True,
    doUnmerged=True,
    minPolynomialOrder=2,
    maxPolynomialOrder=2
)
# Out:
# [18, 19, 20]
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 1.0960e+05 ... 0.0000e+00 ...          5 ... 1.0960e+05
# (x0)' = -0.017 1 u1 + -0.243 1 u3 + -0.299 1 u5 + -0.029 1 u7 + -93.288 1 u9
# 0.35753873354350785
# (x0)' = -0.246 1 u5 + -0.297 1 u9 + -93.158 1 u17
# 0.04061176569731928
# (x0)' = -0.242 1 u6 + -0.301 1 u10 + -93.367 1 u18
# 0.07034060733998204
# (x0)' = -0.242 1 u7 + -0.298 1 u11 + -93.431 1 u19
# 0.008705958252725021
#  Iteration ... |y - Xw|^2 ...  a * |w|_2 ...      |w|_0 ... Total error: |y - Xw|^2 + a * |w|_2
#          0 ... 2.7360e+12 ... 0.0000e+00 ...          5 ... 2.7360e+12
# (x0)' = -95209.814 1 u1 +  406.671 1 u3 +  790.412 1 u5 +  1474.718 1 u7 +  3798.586 1 u9
# 0.9988119576396879
# (x0)' = -97825.689 1 u1 +  110.534 1 u5 +  202.003 1 u9 +  378.047 1 u13 +  894.407 1 u17
# 0.9999178482167901
# ...
